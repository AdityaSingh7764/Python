# %% [markdown]
# # **1. OOP**
# *  In OOP (Object Oriented Programming) you can make your own datatypes for real world applications.

# %% [markdown]
# # **2. Class**
#
#
# *  Class is a blueprint that tells how a object will behave of that class.
# *  Example- Car is a class and WagonR, GWagon, XUV are objects of that class.
# *  Class is created using Pascal case syntax.
# *  There are two types of classes :
# <br>
# <tb> Built In Classes
# <br>
# <tb> User Defined Classes

# %%
L=[1,2,3,4]        # Here List is a predefined class

print(type(L))     # And L is a object of list class
# Out:
# <class 'list'>

# %%
L.append(5)       # List Class has a Object Function Append

print(L)

# %% [markdown]
# ### **Class -**
#
# *  Data or Property - Top Speed, Mileage, Capacity
# *  Functions or Behaviour - Average Speed

# %% [markdown]
# # **3. Object**
#
# *  Object is a instance of the class.

# %% [markdown]
# ### Syntax for creating an object
#
# Object_Name = Class_Name()

# %%
# Object Literal
L = [1,2,3]

L = list()
print(type(L))
print(L)
# Out:
# <class 'list'>
# []

# %%
S = str()
print(type(S))
# Out:
# <class 'str'>

# %%
# ATM Machine

class Atm:

  # Constructor (Function inside Class)(Used when you want to use variable inside class)
  def __init__(self): # Constructor is a special function because it is executed automatically
    self.pin = ''
    self.balance = 0
    print("Automatically Executed")
    self.menu()

  def menu(self):
    user_input = input("""
    How can I help
    1. Create Pin
    2. Change Pin
    3. Check Balance
    4. Withdraw
    5. Exit
    """)

    if user_input == '1':
      # Create Pin
      self.create_pin()
    elif user_input == '2':
      # Change Pin
      self.change_pin()
    elif user_input == '3':
      # Check Balance
      self.check_balance()
    elif user_input == '4':
      # Withdraw
      self.user_withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input("Enter Your Pin: ")
    self.pin = user_pin


    user_balance = int(input("Enter Balance: "))
    self.balance = user_balance

    print("Pin Created Successfully")
    self.menu()

  def change_pin(self):
    old_pin = input("Enter old pin: ")
    if old_pin == self.pin:
        # Let him/her change the pin
        new_pin=input("Enter new pin: ")
        self.pin=new_pin
        print("Pin Changed Successfully")
        self.menu()

    else:
      print("Cannot change pin")
      self.menu()

  def check_balance(self):
    user_pin=input("Enter you pin: ")
    if user_pin == self.pin:
      print("Your Balance: ",self.balance)
    else:
      print("Incorrect Pin")

  def user_withdraw(self):
    user_pin=input("Enter the pin: ")
    if user_pin == self.pin:
      user_amount=int(input("Enter withdraw amount: "))
      if user_amount < self.balance:
        print("Successfully given: ",user_amount)
        print("Remaining balance: ",self.balance-user_amount)
        self.balance=self.balance-user_amount
      else:
        print("Insufficient balance")
        self.menu()
    else:
      print("Incorrect Pin")
      self.menu()

# %%
Obj = Atm()
print(type(Obj))
# Out:
# <class '__main__.Atm'>

# %%
Obj.pin
# Out:
# ''

# %%
Obj1 = Atm()
# Out:
# Automatically Executed

# %%
Obj2 = Atm()
# Out:
# Automatically Executed
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     1
# Enter Your Pin: 1234
# Enter Balance: 5000
# Pin Created Successfully

# %%
Obj3 = Atm()
# Out:
# Automatically Executed
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     1
# Enter Your Pin: 1234
# Enter Balance: 5000
# Pin Created Successfully
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     2
# Enter old pin: 1235
# Cannot change pin
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     2
# Enter old pin: 1234
# Enter new pin: 12345
# Pin Changed Successfully
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     5

# %%
Obj_4 = Atm()
# Out:
# Automatically Executed
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     1
# Enter Your Pin: 1234
# Enter Balance: 5000
# Pin Created Successfully
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     3
# Enter you pin: 1234
# Your Balance:  5000

# %%
Obj5 = Atm()
# Out:
# Automatically Executed
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     1
# Enter Your Pin: 1234
# Enter Balance: 5000
# Pin Created Successfully
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     4
# Enter the pin: 1234
# Enter withdraw amount: 6000
# Insufficient balance
#
#     How can I help
#     1. Create Pin
#     2. Change Pin
#     3. Check Balance
#     4. Withdraw
#     5. Exit
#     4
# Enter the pin: 1234
# Enter withdraw amount: 3000
# Successfully given:  3000
# Remaining balance:  2000

# %% [markdown]
# # **4. Method Vs Function**

# %% [markdown]
# *   **Method: Functions inside class is called Method**
# *   **Function: Independent Functions outside class is called Function**

# %%
L=[1,2,3,4]
len(L)   # Function (Independent Function used for different datatypes, Outside the list class)
L.append(4) # Method (Used by List datatypes, Inside the list class)

# %% [markdown]
# ## **Contructor**
#
# *  Constructor is a special method that automatically triggers after creation of Object.
#
# *  It is used where you do configuration work or task like connecting to database and connection to online service automatically without depending on the customer.

# %%
class PrintStat:

  def __init__(self):
    print('Hi')

obj = PrintStat()
# Out:
# Hi

# %% [markdown]
# ## **Self**
# *   **Self is a current object**
# *   **Self is a instance of class**

# %% [markdown]
# # **5. Magic Method**

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num=self.num*other.den + other.num*self.den
    new_den=self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num=self.num*other.den - other.num*self.den
    new_den=self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num=self.num*other.num
    new_den=self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num=self.num*other.den
    new_den=self.den*other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
Fr=Fraction(1,2)
print(type(Fr))
print(Fr)
# Out:
# <class '__main__.Fraction'>
# ...

# %%
Fr1=Fraction(1,2)
print(Fr1)
# Out:
# 1/2

# %%
Fr1=Fraction(3,4)
Fr2=Fraction(1,2)
print(Fr1+Fr2)
# Out:
# 10/8

# %%
Fr1=Fraction(3,4)
Fr2=Fraction(1,2)
print(Fr1-Fr2)
# Out:
# 2/8

# %%
Fr1=Fraction(3,4)
Fr2=Fraction(1,2)
print(Fr1*Fr2)
# Out:
# 6/4

# %%
Fr1.convert_to_decimal()
# Out:
# 0.75
