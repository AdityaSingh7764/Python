# %% [markdown]
# # Reading JSON to CSV

# %%
import pandas as pd
import numpy as np

# %%
Data = '{"Employee_Name": "Aditya", "Email": "aditya@gmail.com","Job": [{"title1":"Senior", "title2":"AI Engineer"}]}'

# %%
pd.read_json(Data)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_11536\131570499.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(Data)
#   Employee_Name             Email  \
# 0        Aditya  aditya@gmail.com
#
#                                              Job
# 0  {'title1': 'Senior', 'title2': 'AI Engineer'}

# %%
df=pd.read_csv('WineQT.csv', header=None)

# %%
df.head()
# Out:
#               0                 1            2               3          4   \
# 0  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 1            7.4               0.7          0.0             1.9      0.076
# 2            7.8              0.88          0.0             2.6      0.098
# 3            7.8              0.76         0.04             2.3      0.092
# 4           11.2              0.28         0.56             1.9      0.075
#
#                     5                     6        7     8          9   \
# 0  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 25.0                  67.0   0.9968   3.2       0.68
# 3                 15.0                  54.0    0.997  3.26       0.65
# 4                 17.0                  60.0    0.998  3.16       0.58
#
#         10       11  12
# 0  alcohol  quality  Id
# 1      9.4        5   0
# 2      9.8        5   1
# 3      9.8        5   2
# 4      9.8        6   3

# %%
df.to_csv('WineQT.csv')

# %%
df.to_json(orient='records')
# Out:
# '[{"0":"fixed acidity","1":"volatile acidity","2":"citric acid","3":"residual sugar","4":"chlorides","5":"free sulfur dioxide","6":"total sulfur dioxide","7":"density","8":"pH","9":"sulphates","10":"alcohol","11":"quality","12":"Id"},{"0":"7.4","1":"0.7","2":"0.0","3":"1.9","4":"0.076","5":"11.0","6":"34.0","7":"0.9978","8":"3.51","9":"0.56","10":"9.4","11":"5","12":"0"},{"0":"7.8","1":"0.88","2":"0.0","3":"2.6","4":"0.098","5":"25.0","6":"67.0","7":"0.9968","8":"3.2","9":"0.68","10":"9.8","11":"5","12":"1"},{"0":"7.8","1":"0.76","2":"0.04","3":"2.3","4":"0.092","5":"15.0","6":"54.0","7":"0.997","8":"3.26","9":"0.65","10":"9.8","11":"5","12":"2"},{"0":"11.2","1":"0.28","2":"0.56","3":"1.9","4":"0.075","5":"17.0","6":"60.0","7":"0.998","8":"3.16","9":"0.58","10":"9.8","11":"6","12":"3"},{"0":"7.4","1":"0.7","2":"0.0","3":"1.9","4":"0.076","5":"11.0","6":"34.0","7":"0.9978","8":"3.51","9":"0.56","10":"9.4","11":"5","12":"4"},{"0":"7.4","1":"0.66","2":"0.0","3":"1.8","4":"0.075","5":"13.0","6":"40.0","7":"0.9978","8":"3.51","9":"0.56","10":"9.4","11":"5","12":"5"},{"0":"7.9","1":"0.6","2":"0.06","3":"1.6","4":"0.069","5":"15.0","6":"59.0","7":"0.9964","8":"3.3","9":"0.46","10":"9.4","11":"5","12":"6"},{"0":"7.3","1":"0.65","2":"0.0","3":"1.2","4":"0.065","5":"15.0","6":"21.0","7":"0.9946","8":"3.39","9":"0.47","10":"10.0","11":"7","12":"7"},{"0":"7
# %% [markdown]
# # Reading HTML Content

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'
df = pd.read_html(url)

# %%
df[0]
# Out:
#                                Bank Name               City          State  \
# 0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 1                          Citizens Bank           Sac City           Iowa
# 2               Heartland Tri-State Bank            Elkhart         Kansas
# 3                    First Republic Bank      San Francisco     California
# 4                         Signature Bank           New York       New York
# 5                    Silicon Valley Bank        Santa Clara     California
# 6                      Almena State Bank             Almena         Kansas
# 7             First City Bank of Florida  Fort Walton Beach        Florida
# 8                   The First State Bank      Barboursville  West Virginia
# 9                     Ericson State Bank            Ericson       Nebraska
#
#     Cert                 Aquiring Institution       Closing Date   Fund
# 0  27332    Fulton Bank, National Association     April 26, 2024  10546
# 1   8758            Iowa Trust & Savings Bank   November 3, 2023  10545
# 2  25851               Dream First Bank, N.A.      July 28, 2023  10544
# 3  59017            JPMorgan Chase Bank, N.A.        May 1, 2023  10543
# 4  57053                  Flagstar Bank, N.A.     March 12, 2023  10540
# 5  24735  First Citizens Bank & Trust Company     March 10, 2023  10539
# 6  15426                          Equity Bank   October 23, 2020  10538
# 7  16748            United Fidelity Bank, fsb   October 16, 2020  10537
# 8  14361                       MVB Bank, Inc.      April 3, 2020  10536
# 9  18265           Farmers and Merchants Bank  February 14, 2020  10535

# %%
type(df)
# Out:
# list

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Reading Excel File

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('xls_example.xls')

# %%
df.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %% [markdown]
# ## Pickling
#
# All pandas objects are equipped with to_pickle methods which use Python's cPickle module to save data structures to disk using the pickle format

# %%
df.to_pickle('df')

# %%
df=pd.read_pickle('df')

# %%
df.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
